# %% [markdown]
# # NIPUN Compass — Insights Exploration
#
# **Owner: Dharun Kumar (solo — no AI output in this notebook)**
#
# Instructions from CLAUDE.md Section 10:
# > Dharun fills this in solo. Write 5 insights in your own words:
# > 2 reading, 2 math, 1 cross-cutting. Specific numbers, specific states.
#
# ---

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/processed/aser_long.csv')
df.head()
